# %% [markdown]
# # Chamando flows do Langflow via API
#
# Este notebook demonstra como carregar a API key gerada automaticamente e chamar um flow do Langflow.

# %% [markdown]
# ## 1. Carregar credenciais

# %%
from dotenv import load_dotenv
import os

# /config é o volume compartilhado com o serviço langflow-init
load_dotenv("/config/langflow.env")

LANGFLOW_URL = os.environ["LANGFLOW_URL"]
API_KEY      = os.environ["LANGFLOW_API_KEY"]

print(f"LANGFLOW_URL : {LANGFLOW_URL}")
print(f"LANGFLOW_API_KEY : {API_KEY[:12]}{'*' * 20}")
# Out:
# LANGFLOW_URL : http://langflow:7860
# LANGFLOW_API_KEY : sk-_Su73gDcR********************

# %% [markdown]
# ## 2. Listar flows disponíveis

# %%
import requests

headers = {"x-api-key": API_KEY}

resp = requests.get(f"{LANGFLOW_URL}/api/v1/flows/", headers=headers)
resp.raise_for_status()

flows = resp.json()
for flow in flows:
    print(f"{flow['id']}  →  {flow['name']}")
# Out:
# 1f527914-cb01-4513-8c60-39367c382746  →  Invoice Summarizer
# 14880218-fcdd-416c-a028-24f1306798d9  →  Sequential Tasks Agents
# 5e3c8b9e-f3aa-454f-86ce-1d696496cd76  →  Twitter Thread Generator
# c8318b5f-564c-44eb-bd66-4bc88a452bdf  →  Blog Writer
# 426a72a8-ccfe-4345-8592-829a84f0074d  →  Vector Store RAG
# 7fbfebe1-6a12-4703-8d29-1f59f453ed85  →  Image Sentiment Analysis
# 104d7185-8827-42f0-9a6b-66853c9b50aa  →  Meeting Summary
# 660f61fb-ac6a-47de-9238-38fc9c4653d3  →  Pokédex Agent
# 61e5bc4f-037a-4c7e-97de-c34896f3eea0  →  Basic Prompt Chaining
# fa5de6f8-df50-44aa-8772-a1fa2de1ffe7  →  Basic Prompting
# 3d123043-e0d8-4fb6-83a4-26b4ba7ea3c9  →  Memory Chatbot
# 3fa39c7a-41f2-43d2-afd1-4a5ec9fe062c  →  Simple Agent
# 5d09d3e8-91f4-4295-a7f5-ea5fc19f7eac  →  Instagram Copywriter
# 53d910cb-a416-4011-8baa-2eba0c93a248  →  Research Agent
# dc3a1138-0258-4975-8438-929a8033751c  →  Custom Component Generator
# d8494d55-95e0-43fe-b94a-442e4abe194a  →  News Aggregator
# 30bd4e37-a980-4041-9079-c10cd1f73988  →  Travel Planning Agents
# 039044fe-04f6-4e9b-9b90-3e10fc0cedcf  →  Social Media Agent
# 40cef714-20b9-4c4d-b114-b7383113553b  →  NVIDIA RTX Remix
# 2b480b7c-97ea-4886-b424-986780f28f96  →  Financial Report Parser
# 4150212e-c7ad-40f5-a737-52d7029c021c  →  Price Deal Finder
# 701c4fc1-913f-4a5f-9747-df0acc2a247d  →  SaaS Pricing
# a5112f1e-340c-4bf8-930b-0dfb5b91f99a  →  YouTube Analysis
# 8f344528-58f3-4598-856e-c195485e7cdd  →  Market Research
# 0e49caa9-6e7b-41d5-b436-ec322ccdc1b4  →  Research Translation Loop
# a146bc18-7bf6-4305-80dc-7608ed275bdc  →  Portfolio Website Code Generator
# 79afa7dd-1c6c-42ea-90d7-720291f8c317  →  Text Sentiment Analysis
# 22e581de-749e-4194-ab09-c8f1f4b7a85b  →  SEO Keyword Generator
# a08454d8-ec90-4a82-ba68-dd76c764640a  →  Document Q&A
# 6e62abdd-8a5f-45f1-a17c-141fadc9d107  →  Search agent
# 91b21f49-8277-41a1-9a13-223e0af50afa  →  Hybrid Search RAG
# f0090e0e-33b8-42ad-920c-692ea3e8974d  →  Knowledge Base
# 4eb8ac80-dbf9-4d8e-84fc-0240cead8061  →  Basic Prompting

# %% [markdown]
# ## 3. Chamar um flow
#
# Substitua `FLOW_ID` pelo ID do flow listado acima.

# %%
FLOW_ID = "4eb8ac80-dbf9-4d8e-84fc-0240cead8061"

payload = {
    "input_value": "Olá! Quem é você?",
    "input_type": "chat",
    "output_type": "chat",
}

resp = requests.post(
    f"{LANGFLOW_URL}/api/v1/run/{FLOW_ID}",
    json=payload,
    headers=headers,
)
resp.raise_for_status()
resp.json()
# Out:
# {'session_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#  'outputs': [{'inputs': {'input_value': 'Olá! Quem é você?'},
#    'outputs': [{'results': {'message': {'text_key': 'text',
#        'data': {'timestamp': '2026-05-06 03:39:11 UTC',
#         'sender': 'Machine',
#         'sender_name': 'AI',
#         'session_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#         'context_id': '',
#         'text': 'Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.\n\nSe quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.  \nPor exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.\n\nO que você quer criar?',
#         'files': [],
#         'error': False,
#         'edit': False,
#         'properties': {'text_color': None,
#          'background_color': None,
#          'edited': False,
#          'source': {'id': 'LanguageModelComponent-ai5sx',
#           'display_name': 'Language Model',
#           'source': 'gpt-5.4-mini'},
#          'icon': None,
#          'allow_markdown': False,
#          'positive_feedback': None,
#          'state': 'complete',
#          'targets': [],
#          'usage': {'input_tokens': 38,
#           'output_tokens': 92,
#           'total_tokens': 130},
#          'build_duration': None},
#         'category': 'message',
#         'content_blocks': [],
#         'id': '5e363af8-657d-46c7-a30e-94ce86fa171d',
#         'flow_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#         'session_metadata': None,
#         'duration': None},
#        'default_value': '',
#        'text': 'Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.\n\nSe quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.  \nPor exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.\n\nO que você quer criar?',
#        'sender': 'Machine',
#        'sender_name': 'AI',
#        'files': [],
#        'session_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#        'context_id': '',
#        'timestamp': '2026-05-06T03:39:11+00:00',
#        'flow_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#        'error': False,
#        'edit': False,
#        'properties': {'text_color': None,
#         'background_color': None,
#         'edited': False,
#         'source': {'id': 'LanguageModelComponent-ai5sx',
#          'display_name': 'Language Model',
#          'source': 'gpt-5.4-mini'},
#         'icon': None,
#         'allow_markdown': False,
#         'positive_feedback': None,
#         'state': 'complete',
#         'targets': [],
#         'usage': {'input_tokens': 38,
#          'output_tokens': 92,
#          'total_tokens': 130},
#         'build_duration': None},
#        'category': 'message',
#        'content_blocks': [],
#        'duration': None,
#        'session_metadata': None}},
#      'artifacts': {'message': 'Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.\n\nSe quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.  \n\nPor exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.\n\nO que você quer criar?',
#       'sender': 'Machine',
#       'sender_name': 'AI',
#       'files': [],
#       'type': 'object'},
#      'outputs': {'message': {'message': 'Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.\n\nSe quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.  \nPor exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.\n\nO que você quer criar?',
#        'type': 'text'}},
#      'logs': {'message': []},
#      'messages': [{'message': 'Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.\n\nSe quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.  \n\nPor exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.\n\nO que você quer criar?',
#        'sender': 'Machine',
#        'sender_name': 'AI',
#        'session_id': '4eb8ac80-dbf9-4d8e-84fc-0240cead8061',
#        'stream_url': None,
#        'component_id': 'ChatOutput-zFjiv',
#        'files': [],
#        'type': 'text'}],
#      'timedelta': None,
#      'duration': None,
#      'component_display_name': 'Chat Output',
#      'component_id': 'ChatOutput-zFjiv',
#      'used_frozen_result': False,
#      'token_usage': None}]}]}

# %% [markdown]
# ## 4. Extrair só o texto da resposta

# %%
result = resp.json()

text = (
    result["outputs"][0]["outputs"][0]
    ["results"]["message"]["text"]
)
print(text)
# Out:
# Olá! Eu sou um assistente de IA — posso ajudar você a responder perguntas, escrever textos, gerar ideias, programar, aprender conceitos e até planejar projetos.
#
# Se quiser, posso também te ajudar a **começar a construir algo novo** com IA, passo a passo.
# Por exemplo: um chatbot, um assistente para negócios, um app com geração de texto, ou uma automação inteligente.
#
# O que você quer criar?
